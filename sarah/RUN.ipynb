# %%
import sys
path = r"C:\Users\sagarwal4\Downloads\pymarketsim-master\pymarketsim-master"
if path not in sys.path:
    sys.path.insert(0, path)

from marketsim.rl.train_dqn import run_rl_parameter_doe
from marketsim.rl.train_dqn import run_latency_doe
from marketsim.rl.train_dqn import run_fundamental_doe
from marketsim.rl.train_dqn import run_fundamental_latency_doe

# %%
# (a) parameter sensitivity
results_rl = run_rl_parameter_doe(output_root="runs_rl_param")
# Out:
# Saving outputs to: c:\Users\sagarwal4\Downloads\pymarketsim-master\pymarketsim-master\sarah\runs_rl_param\dqn_AAPL_XOM_A_pen1_tf4_20260413_161520_227331
# Ep 0000 | Return   -11.6679 | Steps  10 | Invalid   1 | Eps 0.9981 | Loss None
# Ep 0001 | Return    -8.3885 | Steps   7 | Invalid   2 | Eps 0.9968 | Loss None
# Ep 0002 | Return   -15.4461 | Steps  12 | Invalid   6 | Eps 0.9945 | Loss None
# Ep 0003 | Return    -4.0345 | Steps   5 | Invalid   4 | Eps 0.9935 | Loss None
# Ep 0004 | Return   -20.2523 | Steps   8 | Invalid   1 | Eps 0.9920 | Loss None
# Ep 0005 | Return   -10.2543 | Steps   8 | Invalid   4 | Eps 0.9905 | Loss None
# Ep 0006 | Return   -11.5997 | Steps  11 | Invalid   4 | Eps 0.9884 | Loss None
# Ep 0007 | Return   -31.3242 | Steps  14 | Invalid   4 | Eps 0.9858 | Loss None
# Ep 0008 | Return   -11.7071 | Steps   6 | Invalid   3 | Eps 0.9846 | Loss None
# Ep 0009 | Return   -15.2226 | Steps  11 | Invalid   3 | Eps 0.9825 | Loss None
# ...

# %%
# (b) latency vs no latency
results_latency = run_latency_doe(output_root="runs_latency")
# Out:
# Saving outputs to: c:\Users\sagarwal4\Downloads\pymarketsim-master\pymarketsim-master\sarah\runs_latency\dqn_AAPL_XOM_hist_lat0_pen1_tf1_20260413_160341_484337
# Ep 0000 | Return   -11.6679 | Steps  10 | Invalid   1 | Eps 0.9981 | Loss None
# Ep 0001 | Return    -8.3885 | Steps   7 | Invalid   2 | Eps 0.9968 | Loss None
# Ep 0002 | Return   -15.4461 | Steps  12 | Invalid   6 | Eps 0.9945 | Loss None
# Ep 0003 | Return    -4.0345 | Steps   5 | Invalid   4 | Eps 0.9935 | Loss None
# Ep 0004 | Return   -20.2523 | Steps   8 | Invalid   1 | Eps 0.9920 | Loss None
# Ep 0005 | Return   -10.2543 | Steps   8 | Invalid   4 | Eps 0.9905 | Loss None
# Ep 0006 | Return   -11.5997 | Steps  11 | Invalid   4 | Eps 0.9884 | Loss None
# Ep 0007 | Return   -31.3242 | Steps  14 | Invalid   4 | Eps 0.9858 | Loss None
# Ep 0008 | Return   -11.7071 | Steps   6 | Invalid   3 | Eps 0.9846 | Loss None
# Ep 0009 | Return   -15.2226 | Steps  11 | Invalid   3 | Eps 0.9825 | Loss None
# ...

# %%
# (c) historical vs synthetic fundamental
results_fundamental = run_fundamental_doe(output_root="runs_fundamental")
# Out:
# Saving outputs to: c:\Users\sagarwal4\Downloads\pymarketsim-master\pymarketsim-master\sarah\runs_fundamental\dqn_AAPL_XOM_hist_pen1_tf1_20260413_153225_905924
# Ep 0000 | Return   -11.6679 | Steps  10 | Invalid   1 | Eps 0.9981 | Loss None
# Ep 0001 | Return    -8.3885 | Steps   7 | Invalid   2 | Eps 0.9968 | Loss None
# Ep 0002 | Return   -15.4461 | Steps  12 | Invalid   6 | Eps 0.9945 | Loss None
# Ep 0003 | Return    -4.0345 | Steps   5 | Invalid   4 | Eps 0.9935 | Loss None
# Ep 0004 | Return   -20.2523 | Steps   8 | Invalid   1 | Eps 0.9920 | Loss None
# Ep 0005 | Return   -10.2543 | Steps   8 | Invalid   4 | Eps 0.9905 | Loss None
# Ep 0006 | Return   -11.5997 | Steps  11 | Invalid   4 | Eps 0.9884 | Loss None
# Ep 0007 | Return   -31.3242 | Steps  14 | Invalid   4 | Eps 0.9858 | Loss None
# Ep 0008 | Return   -11.7071 | Steps   6 | Invalid   3 | Eps 0.9846 | Loss None
# Ep 0009 | Return   -15.2226 | Steps  11 | Invalid   3 | Eps 0.9825 | Loss None
# ...

# %%
# (b) and (c)
results_combo = run_fundamental_latency_doe(output_root="runs_fundamental_latency")
# Out:
# Saving outputs to: c:\Users\sagarwal4\Downloads\pymarketsim-master\pymarketsim-master\sarah\runs_fundamental_latency\dqn_AAPL_XOM_hist_lat0_20260413_154729_156116
# Ep 0000 | Return   -11.6679 | Steps  10 | Invalid   1 | Eps 0.9981 | Loss None
# Ep 0001 | Return    -8.3885 | Steps   7 | Invalid   2 | Eps 0.9968 | Loss None
# Ep 0002 | Return   -15.4461 | Steps  12 | Invalid   6 | Eps 0.9945 | Loss None
# Ep 0003 | Return    -4.0345 | Steps   5 | Invalid   4 | Eps 0.9935 | Loss None
# Ep 0004 | Return   -20.2523 | Steps   8 | Invalid   1 | Eps 0.9920 | Loss None
# Ep 0005 | Return   -10.2543 | Steps   8 | Invalid   4 | Eps 0.9905 | Loss None
# Ep 0006 | Return   -11.5997 | Steps  11 | Invalid   4 | Eps 0.9884 | Loss None
# Ep 0007 | Return   -31.3242 | Steps  14 | Invalid   4 | Eps 0.9858 | Loss None
# Ep 0008 | Return   -11.7071 | Steps   6 | Invalid   3 | Eps 0.9846 | Loss None
# Ep 0009 | Return   -15.2226 | Steps  11 | Invalid   3 | Eps 0.9825 | Loss None
# ...

# %%
# stochastic latency
